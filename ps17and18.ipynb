# %%
pip install gradio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 54.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.1/288.1 kB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.6/136.6 kB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.2 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
import nltk
from nltk import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stop_words = stopwords.words('english')

# %%
sent="Hello I am Avinash Jadhav. I am from Nashik District. I am a computer engineer."

# %%
token = word_tokenize(sent)
cleaned_token = []
for word in token:
  if word not in stop_words:
    cleaned_token.append(word)

print("Unclean version ", token)
print("Clean Version", cleaned_token)
# Out:
# Unclean version  ['Hello', 'I', 'am', 'Avinash', 'Jadhav', '.', 'I', 'am', 'from', 'Nashik', 'District', '.', 'I', 'am', 'a', 'computer', 'engineer', '.']
# Clean Version ['Hello', 'I', 'Avinash', 'Jadhav', '.', 'I', 'Nashik', 'District', '.', 'I', 'computer', 'engineer', '.']

# %%
#defining a function for stopword removal
def remove_stop(text):
    return ",".join([word for word in str(text).split() if word not in stop_words])

# %%
demo3 = gr.Interface(fn=remove_stop, inputs="text", outputs="text")
demo3.launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %% [markdown]
# For ps18
# we have to make any text file
#
# after that open and read it by following commands
#
# f=open('sample.txt','r')
# filecontent=f.read()
# filecontent

# %%
from google.colab import drive
drive.mount('/content/gdrive') #ignore this due i am performing assignments on google colab i have to give access of my drive so i used it in jupyter notebook no need
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
fs=open('/content/gdrive/My Drive/Colab Notebooks/sample.txt') #ignore directory which i given. here we have to put our directory where we save file in pc

# %%
filecontent=fs.read()
filecontent
# Out:
# 'Hello I am Avinash Jadhav. I am from Nashik District. I am a computer engineer.'

# %%
token = word_tokenize(filecontent)
cleaned_token = []
for word in token:
  if word not in stop_words:
    cleaned_token.append(word)

print("Unclean version ", token)
print("Clean Version", cleaned_token)
# Out:
# Unclean version  ['Hello', 'I', 'am', 'Avinash', 'Jadhav', '.', 'I', 'am', 'from', 'Nashik', 'District', '.', 'I', 'am', 'a', 'computer', 'engineer', '.']
# Clean Version ['Hello', 'I', 'Avinash', 'Jadhav', '.', 'I', 'Nashik', 'District', '.', 'I', 'computer', 'engineer', '.']

# %%
#defining a function for stopword removal
def remove_stop(text):
    return ",".join([word for word in str(text).split() if word not in stop_words])

# %%
remove_stop(filecontent)
# Out:
# 'Hello,I,Avinash,Jadhav.,I,Nashik,District.,I,computer,engineer.'
