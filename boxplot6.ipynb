# %%
import  pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/sample_data/Iris (1).csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
sns.boxplot(df['SepalLengthCm'])
# Out:
# <Axes: >

# %%
sns.boxplot(df.iloc[:,1:5])
# Out:
# <Axes: >

# %%
fig,axs=plt.subplots(2,2,figsize=(8,9))
sns.histplot(data=df,x='SepalLengthCm',bins=10,color='blue',ax=axs[0,0],kde='True')
sns.histplot(data=df,x='SepalWidthCm',bins=10,color='red',ax=axs[0,1],kde='True')
sns.histplot(data=df,x='PetalLengthCm',bins=10,color='green',ax=axs[1,0],kde='True')
sns.histplot(data=df,x='PetalWidthCm',bins=10,color='blue',ax=axs[1,1],kde='True')
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
 fig,axs=plt.subplots(2,2,figsize=(9,10))
 sns.boxplot(data=df,y='SepalLengthCm',x='Species',ax=axs[0,0])
 sns.boxplot(data=df,y='PetalLengthCm',x='Species',ax=axs[0,1])
 sns.boxplot(data=df,y='SepalWidthCm',x='Species',ax=axs[1,0])
 sns.boxplot(data=df,y='PetalWidthCm',x='Species',ax=axs[1,1])
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>
