# %%
import pandas as pd

# %%
df=pd.read_csv('housing.csv')

# %%
df
# Out:
#    area   price
# 0  2600  555000
# 1  3000  666000
# 2  4000  777000
# 3  5000  888000
# 4  6000  999000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['area'],df['price'])

# %%
plt.scatter(df.area,df.price)

# %%
from sklearn import linear_model

# %%
import numpy as np

# %%
reg=linear_model.LinearRegression()

# %%
x=np.array(df.area).reshape(-1,1)

# %%
y=np.array(df.price).reshape(-1,1)

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.predict([[8000]])
# Out:
# array([[1257474.64503043]])

# %%
reg.coef_
# Out:
# array([[123.8336714]])

# %%
reg.intercept_
# Out:
# array([266805.27383367])

# %%
f=(123.8336714*8000)+266805.27383367

# %%
f
# Out:
# 1257474.6450336701
