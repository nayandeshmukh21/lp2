# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from pandas import get_dummies

# %%
data = pd.read_csv('iris.csv')
data11 = pd.read_csv('iris.csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   148.000000
# mean       5.844295     3.051678      3.774497     1.212162
# std        0.830775     0.434120      1.759651     0.759332
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   149 non-null    float64
#  2   petal_length  149 non-null    float64
#  3   petal_width   148 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.isna().sum()
# Out:
# sepal_length    1
# sepal_width     1
# petal_length    1
# petal_width     2
# species         0
# dtype: int64

# %%
data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df = data.copy()

# %%
df1 = data.copy()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris = sns.load_dataset('iris')
 
sns.set_style("whitegrid")
 
sns.FacetGrid(iris, hue ="species",
              height = 6).map(plt.scatter,
                              'sepal_length',
                              'petal_length').add_legend()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Without using group by function

# %%
data.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
group1 = df[df.species == "Iris-setosa"]
group2 = df[df.species == "Iris-versicolor"]
group3 = df[df.species == "Iris-virginica"]
group3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 106           4.9          2.5           4.5          1.7  Iris-virginica
# 107           7.3          2.9           6.3          1.8  Iris-virginica
# 108           6.7          2.5           5.8          1.8  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 110           6.5          3.2           5.1          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# ...

# %% [markdown]
# ## Iris-setosa

# %%
group1.describe()

# %% [markdown]
# ## Iris-versicolor

# %%
group2.describe()

# %% [markdown]
# ##  Iris-virginica

# %%
group3.describe()

# %% [markdown]
# <img src="flowers.png"/>

# %% [markdown]
# # Using Group by function

# %%
grouped_data = df.groupby(df['species'])

# %%
grouped_data.describe()
# Out:
#                 sepal_length
#                        count      mean       std  min    25%  50%  75%  max
# species
# Iris-setosa             49.0  4.991837  0.341465  4.3  4.800  5.0  5.2  5.8  \
# Iris-versicolor         50.0  5.936000  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica          50.0  6.588000  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 sepal_width            ... petal_length      petal_width
#                       count      mean  ...          75%  max       count
# species                                ...
# Iris-setosa            49.0  3.418367  ...        1.600  1.9        48.0  \
# Iris-versicolor        50.0  2.770000  ...        4.600  5.1        50.0
# Iris-virginica         50.0  2.974000  ...        5.875  6.9        50.0
#
#
#                      mean       std  min  25%  50%  75%  max
# species
# Iris-setosa      0.245833  0.109074  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor  1.326000  0.197753  1.0  1.2  1.3  1.5  1.8
# ...

# %%
grouped_data.count()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa                49           49            49           48
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %%
grouped_data.groups.keys()
# Out:
# dict_keys(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'])

# %%
print(len(grouped_data.groups.keys()))
# Out:
# 3

# %%
grouped_data.get_group(data.species.unique()[0]).head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
grouped_data.get_group(data.species.unique()[1]).head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor

# %%
grouped_data.get_group(data.species.unique()[2]).head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica

# %%
grouped_data.ngroup().nunique()
# Out:
# 3

# %%
data.isna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# sepal_length    1
# sepal_width     1
# petal_length    1
# petal_width     2
# species         0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 5

# %%
data[data.isna().any(axis=1)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 11           4.8          3.4           1.6          NaN  Iris-setosa
# 12           4.8          3.0           NaN          0.1  Iris-setosa
# 15           NaN          4.4           1.5          0.4  Iris-setosa
# 20           5.4          NaN           1.7          0.2  Iris-setosa
# 27           5.2          3.5           1.5          NaN  Iris-setosa

# %%
df.fillna(0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.dropna(axis=0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [145 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   148.000000
# mean       5.844295     3.051678      3.774497     1.212162
# std        0.830775     0.434120      1.759651     0.759332
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['sepal_length'].mean()
# Out:
# 5.844295302013423

# %%
df['sepal_length'].replace(np.nan,df['sepal_length'].mean(),inplace=True)
df['sepal_width'].replace(np.nan,df['sepal_width'].mean(),inplace=True)
df['petal_length'].replace(np.nan,df['petal_length'].mean(),inplace=True)
df['petal_width'].replace(np.nan,df['petal_width'].mean(),inplace=True)

df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
import seaborn as sns

# %%
sns.boxplot(df['petal_length'])
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
import scipy.stats as st

# %%
st.zscore(df['sepal_length'])
# Out:
# 0     -0.901938
# 1     -1.144298
# 2     -1.386659
# 3     -1.507839
# 4     -1.023118
#          ...
# 145    1.036944
# 146    0.552224
# 147    0.794584
# 148    0.431043
# 149    0.067503
# Name: sepal_length, Length: 150, dtype: float64

# %%
q1 = df['sepal_length'].quantile(0.25)
q2 = df['sepal_length'].quantile(0.50)
q3 = df['sepal_length'].quantile(0.75)

# %%
print(q1,q2,q3)
# Out:
# 5.1 5.8 6.4

# %%
IQR = q3 - q1
IQR
# Out:
# 1.3000000000000007

# %%
UL = q3 + (1.5 * IQR)
LL = q1 - (1.5 * IQR)
print(UL,LL)
# Out:
# 8.350000000000001 3.1499999999999986

# %%
outl_z = pd.DataFrame(np.where((df['sepal_length']>UL)))
outl_z
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
outl1_z = pd.DataFrame(np.where((df['sepal_length']<LL)))
outl1_z
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
df['sepal_length'].mean()
# Out:
# 5.844295302013422

# %%
to_replace = pd.DataFrame(np.where(df['sepal_length']>UL,df['sepal_length'].mean(),df['sepal_length']))
to_replace
# Out:
#        0
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# ..   ...
# 145  6.7
# 146  6.3
# 147  6.5
# 148  6.2
# 149  5.9
#
# [150 rows x 1 columns]

# %%
to_replace = pd.DataFrame(np.where(to_replace[0]<LL,df['sepal_length'].mean(),to_replace[0]))
to_replace
# Out:
#        0
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# ..   ...
# 145  6.7
# 146  6.3
# 147  6.5
# 148  6.2
# 149  5.9
#
# [150 rows x 1 columns]

# %%
temp = df.copy()
temp.drop(index=np.where(temp['sepal_length']>UL)[0],inplace=True)
temp
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df.sepal_length,df.sepal_width)
plt.show()

# %%
#capping and flooring
q_10th = df['sepal_length'].quantile(0.1)
q_90th = df['sepal_length'].quantile(0.9)

temp = df.copy()

print(q_10th,q_90th)

for i in np.where(temp['sepal_length']>UL)[0]:
    if(temp['sepal_length'][i]<q_10th):
        temp.loc[:,('sepal_length')] = q_10th
    else:
        temp.loc[:,('sepal_length')] = q_90th
temp
# Out:
# 4.8 6.9
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
