# %%
import pandas as pd
#1
df=pd.read_csv("IRIS.csv")

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
#2
df.isnull().sum()
# Out:
# sepal_length    1
# sepal_width     1
# petal_length    1
# petal_width     2
# species         0
# dtype: int64

# %%
#3
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   148.000000
# mean       5.844295     3.051678      3.774497     1.212162
# std        0.830775     0.434120      1.759651     0.759332
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#4
df.shape
# Out:
# (150, 5)

# %%
#5
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   149 non-null    float64
#  2   petal_length  149 non-null    float64
#  3   petal_width   148 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df1=pd.read_csv("IRIS.csv")

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df1.select_dtypes(exclude=['object'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df1.select_dtypes(include=['object'])
# Out:
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
df1.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df2=pd.DataFrame(df1,columns=['sepal_width','petal_width'])

# %%
df2=df2.astype(str)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepal_width  150 non-null    object
#  1   petal_width  150 non-null    object
# dtypes: object(2)
# memory usage: 2.5+ KB

# %%
df2
# Out:
#     sepal_width petal_width
# 0           3.5         0.2
# 1           3.0         0.2
# 2           3.2         0.2
# 3           3.1         0.2
# 4           3.6         0.2
# ..          ...         ...
# 145         3.0         2.3
# 146         2.5         1.9
# 147         3.0         2.0
# 148         3.4         2.3
# 149         3.0         1.8
#
# [150 rows x 2 columns]

# %%
df2.convert_dtypes().dtypes
# Out:
# sepal_width    string[python]
# petal_width    string[python]
# dtype: object

# %%
avi=pd.read_csv('timess.csv')

# %%
avi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   values   3 non-null      float64
#  1   name     3 non-null      object
#  2   roll no  3 non-null      int64
#  3   marks    3 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
avi
# Out:
#    values       name  roll no  marks
# 0     1.0     satyam       20  90.25
# 1     2.0    avinash       24  84.75
# 2     3.0  chaitanya       30  63.33

# %%
avi.dtypes
# Out:
# values     float64
# name        object
# roll no      int64
# marks      float64
# dtype: object

# %%
avi=avi.convert_dtypes()

# %%
avi.dtypes
# Out:
# values              Int64
# name       string[python]
# roll no             Int64
# marks             Float64
# dtype: object

# %%
#6
df=pd.get_dummies(data=df, columns=['species'])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2  \
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
#      species_Iris-setosa  species_Iris-versicolor  species_Iris-virginica
# 0                   True                    False                   False
# 1                   True                    False                   False
# ...
